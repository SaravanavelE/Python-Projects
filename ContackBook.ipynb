# %% [markdown]
# <a href="https://colab.research.google.com/github/SaravanavelE/Python-Projects/blob/main/ContackBook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Simple Contact Book Application with Edit Contact Feature

def display_menu():
    print("\nContact Book Menu:")
    print("1. Add Contact")
    print("2. Search Contact")
    print("3. Edit Contact")
    print("4. Delete Contact")
    print("5. View All Contacts")
    print("6. Exit")

def add_contact(contacts):
    name = input("Enter contact name: ").strip()
    if name in contacts:
        print("Contact already exists.")
    else:
        phone = input("Enter contact phone number: ").strip()
        contacts[name] = phone
        print(f"Contact {name} added successfully.")

def search_contact(contacts):
    name = input("Enter the contact name to search: ").strip()
    if name in contacts:
        print(f"{name}: {contacts[name]}")
    else:
        print("Contact not found.")

def edit_contact(contacts):
    name = input("Enter the contact name to edit: ").strip()
    if name in contacts:
        print(f"Current details - {name}: {contacts[name]}")
        new_phone = input("Enter the new phone number: ").strip()
        contacts[name] = new_phone
        print(f"Contact {name} updated successfully.")
    else:
        print("Contact not found.")

def delete_contact(contacts):
    name = input("Enter the contact name to delete: ").strip()
    if name in contacts:
        del contacts[name]
        print(f"Contact {name} deleted successfully.")
    else:
        print("Contact not found.")

def view_all_contacts(contacts):
    if not contacts:
        print("No contacts available.")
    else:
        print("\nAll Contacts:")
        for name, phone in contacts.items():
            print(f"{name}: {phone}")

def main():
    contacts = {}
    while True:
        display_menu()
        choice = input("Enter your choice: ").strip()
        if choice == "1":
            add_contact(contacts)
            print("----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
        elif choice == "2":
            search_contact(contacts)
            print("----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
        elif choice == "3":
            edit_contact(contacts)
            print("----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
        elif choice == "4":
            delete_contact(contacts)
            print("----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
        elif choice == "5":
            view_all_contacts(contacts)
            print("----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
        elif choice == "6":
            print("Exiting Contact Book.")
            print("----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
            break
        else:
            print("Invalid choice. Enter A valid Number.")

main()
# Out:
# Contact Book Menu:
# 1. Add Contact
# 2. Search Contact
# 3. Edit Contact
# 4. Delete Contact
# 5. View All Contacts
# 6. Exit
# Enter your choice: 1
# Enter contact name: saravana
# Enter contact phone number: 9876543210
# Contact saravana added successfully.
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Contact Book Menu:
# 1. Add Contact
# 2. Search Contact
# 3. Edit Contact
# 4. Delete Contact
# 5. View All Contacts
# 6. Exit
# Enter your choice: 1
# Enter contact name: vel
# Enter contact phone number: 9874563210
# Contact vel added successfully.
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Contact Book Menu:
# 1. Add Contact
# 2. Search Contact
# 3. Edit Contact
# ...
